# %% [markdown]
# # 1. Crawler

# %% [markdown]
# The ```WGET``` file is attached in moodle as well as in my [repo](https://github.com/Ehsan2754/information-retrieval/blob/master/templates/2022S/2022S-01/wget.py).  The file content is as following:

# %%
import argparse
import os
import re
import requests


def wget(url, filename):
    # allow redirects - in case file is relocated
    resp = requests.get(url, allow_redirects=True)
    # this can also be 2xx, but for simplicity now we stick to 200
    # you can also check for `resp.ok`
    if resp.status_code != 200:
        print(resp.status_code, resp.reason, 'for', url)
        return
    
    # just to be cool and print something
    print(*[f"{key}: {value}" for key, value in resp.headers.items()], sep='\n')
    print()
    
    # try to extract filename from url
    if filename is None:
        # start with http*, ends if ? or # appears (or none of)
        m = re.search("^http.*/([^/\?#]*)[\?#]?", url)
        filename = m.group(1)
        if not filename:
            raise NameError(f"Filename neither given, nor found for {url}")

    # what will you do in case 2 websites store file with the same name?
    if os.path.exists(filename):
        raise OSError(f"File {filename} already exists")
    
    with open(filename, 'wb') as f:
        f.write(resp.content)
        print(f"File saved as {filename}")


if __name__ == "__main__":
    parser = argparse.ArgumentParser(description='download file.')
    parser.add_argument("-O", type=str, default=None, dest='filename', help="output file name. Default -- taken from resource")
    parser.add_argument("url", type=str, default=None, help="Provide URL here")
    args = parser.parse_args()
    wget(args.url, args.filename)
# Out:
# usage: ipykernel_launcher.py [-h] [-O FILENAME] url
# ipykernel_launcher.py: error: the following arguments are required: url
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %% [markdown]
# ## 1.1. [15] Download and persist #
# Please complete a code for `load()`, `download()` and `persist()` methods of `Document` class. What they do:
# - for a given URL `download()` method downloads binary data and stores in `self.content`. It returns `True` for success, else `False`.
# - `persist()` method saves `self.content` somewhere in file system. We do it to avoid multiple downloads (for caching in other words).
# - `load()` method loads data from hard drive. Returns `True` for success.
#
# Tests checks that your code somehow works.
#
# **NB Passing the test doesn't mean you correctly completed the task.** These are **criteria, which have to be fullfilled**:
# 1. URL is a unique identifier (as it is a subset of URI). Thus, documents with different URLs should be stored in different files. Typical errors: documents from the same domain are overwritten to the same file, URLs with similar endings are downloaded to the same file, etc.
# 2. The document can be not only a text file, but also a binary. Pay attention that if you download `mp3` file, it still can be played. Hint: don't hurry to convert everything to text.

# %%
import requests
from urllib.parse import quote
import hashlib
import re
import argparse
import os
import re
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry


class Document:
    BAD_REQUEST = -1
    FILE_EXISTS = 0
    SUCCESS = 1
    def __alt_wget(self,url, filename):
        # allow redirects - in case file is relocated
        session = requests.Session()
        retry = Retry(connect=3, backoff_factor=0.5)
        adapter = HTTPAdapter(max_retries=retry)
        session.mount('http://', adapter)
        session.mount('https://', adapter)

        resp = requests.get(self.url,allow_redirects=True)
        #  requests.get(url, allow_redirects=True)
        # this can also be 2xx, but for simplicity now we stick to 200
        # you can also check for `resp.ok`
        if resp.status_code != 200:
            print(resp.status_code, resp.reason, 'for', url)
            return (self.BAD_REQUEST,None)
        
        # just to be cool and print something
        print(*[f"{key}: {value}" for key, value in resp.headers.items()], sep='\n')
        print()
        return (self.SUCCESS,resp.content)


    
    def __init__(self, url):
        self.url = url
        # m = re.search("^http.*/([^/\?#]*)[\?#]?", url)
        # self.filename = m.group(1)
        # if not self.filename:
        #     raise NameError(f"Filename neither given, nor found for {url}")
        self.filename = hashlib.sha256(url.encode()).hexdigest()
        
    def get(self):
        if not self.load():
            if not self.download():
                raise FileNotFoundError(self.url)
            else:
                self.persist()
    
    def download(self):
        #TODO download self.url content, store it in self.content and return True in case of success
        result,self.content = self.__alt_wget(self.url,self.filename)
        return (result==self.SUCCESS)
    
    def persist(self):
        #TODO write document content to hard drive

        # what will you do in case websites store file with the same name?
        if os.path.exists(self.filename):
             raise OSError(f"File {self.filename} already exists")
        with open(self.filename, 'wb') as f:
            f.write(self.content)
            print(f"File saved as {self.filename}")
            
    def load(self):
        #TODO load content from hard drive, store it in self.content and return True in case of success
        if not os.path.exists(self.filename):
            return False
        with open(self.filename, 'rb') as f:
            self.content = f.read()
            print(f"File loaded: {self.filename}")
        return True

# %% [markdown]
# ### 1.1.1. Tests ###

# %%
doc = Document('http://sprotasov.ru/data/iu.txt')

doc.get()
assert doc.content, "Document download failed"
assert "Code snippets, demos and labs for the course" in str(doc.content), "Document content error"

doc.get()
assert doc.load(), "Load should return true for saved document"
assert "Code snippets, demos and labs for the course" in str(doc.content), "Document load from disk error"
# Out:
# File loaded: e3f92252000cd79aa00e286a050c7825ff95897ad1c4d62c4e43bf948085d14c
# File loaded: e3f92252000cd79aa00e286a050c7825ff95897ad1c4d62c4e43bf948085d14c
# File loaded: e3f92252000cd79aa00e286a050c7825ff95897ad1c4d62c4e43bf948085d14c

# %% [markdown]
# ## 1.3. [10] Parse HTML ##
# `BeautifulSoap` library is a de facto standard to parse XML and HTML documents in python. Use it to complete `parse()` method that extracts document contents. You should initialize:
# - `self.anchors` list of tuples `('text', 'url')` met in a document. Be aware, there exist relative links (e.g. `../content/pic.jpg`). Use `urllib.parse.urljoin()` to fix this issue.
# - `self.images` list of images met in a document. Again, links can be relative to current page.
# - `self.text` should keep plain text of the document without scripts, tags, comments and so on. You can refer to [this stackoverflow answer](https://stackoverflow.com/a/1983219) for details.
#
# **NB All these 3 criteria must be fulfilled to get full point for the task.**

# %%
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.parse


class HtmlDocument(Document):

    def normalize_link(self, link):
        if link is not None and link[:4] == 'http':
            return link
        return urllib.parse.urljoin(self.url, link)
    
    def parse(self):
        #TODO extract plain text, images and links from the document
        self.get()
        soup = BeautifulSoup(self.content)
        self.anchors = []
        self.images = []
        self.text = ""

        a_links = soup.find_all("a") 
        for a in a_links:
            text = a.getText()
            link = a.get('href')
            self.anchors.append((text, self.normalize_link(link)))

        imgs = soup.find_all("img")
        for img in imgs:
            link = img.get('src')
            self.images.append(self.normalize_link(link))
        
        #TODO get the text using soup.getAll(text=true) and filter unwanted tags as ['style', 'script', 'head', 'title'] e.g. anything not visible
        text = soup.find("body").getText()
        self.text = text.replace('\n','').replace('\r','').strip() if type(text)==str else ""

# %% [markdown]
# ### 1.3.1. Tests ###

# %%
doc = HtmlDocument("http://sprotasov.ru")
doc.get()
doc.parse()

assert "just few links" in doc.text, "Error parsing text"
assert "http://sprotasov.ru/images/gb.svg" in doc.images, "Error parsing images"
assert any(p[1] == "https://twitter.com/07C3" for p in doc.anchors), "Error parsing links"
print(doc.text)
# Out:
# File loaded: 2f3ba9f50c5510bce6a195f516b85dcf0aae989144395037ec0774dec5872b86
# File loaded: 2f3ba9f50c5510bce6a195f516b85dcf0aae989144395037ec0774dec5872b86
# Stanislav Protasov in just few links:Curriculum vitaeGoogle ScholarGitHubResearchGateПубликации в eLibraryFacebookLinkedInResearch with Stas telegram channelПодкаст "Происхождение видов": telegram, iTunes, RSSAutomatic testing system (source code)Книга "Давайте объясню: или зачем программисту математика"Материалы на ПостНаукеTwitter

# %% [markdown]
# ## 1.4. [10] Document analysis ##
# Complete the code for `HtmlDocumentTextData` class. Implement word and sentence splitting (use any method you can propose).
#
# **Criteria of success**:
# 1. Your `get_word_stats()` method should return `Counter` object.
# 2. Don't forget to lowercase your words for counting.
# 3. Sentences should be obtained inside `<body>` tag only.

# %%
from collections import Counter

class HtmlDocumentTextData:
    
    def __init__(self, url):
        self.doc = HtmlDocument(url)
        self.doc.get()
        self.doc.parse()
    
    def get_sentences(self):
        #TODO implement sentence parser
        result = self.doc.text.split('.')
        return result
    
    def get_word_stats(self):
        #TODO return Counter object of the document, containing mapping {`word` -> count_in_doc}
        words =  [item.lower() for sublist in list(map(str.split,self.get_sentences())) for item in sublist] 
        # extracting words from sentences and flattening the list and lowercasing the words.
    
        return Counter(words)

# %% [markdown]
# ### 1.4.1. Tests ###

# %%
doc = HtmlDocumentTextData("https://innopolis.university/")
print(doc.get_word_stats().most_common(10))
assert [x for x in doc.get_word_stats().most_common(10) if x[0] == 'иннополис'], 'иннополис should be among most common'
# Out:
# File loaded: a098b299ac4dd3ffe293ff4f93725462aef38ebd339d74e9bfafdea53a3abfd5
# File loaded: a098b299ac4dd3ffe293ff4f93725462aef38ebd339d74e9bfafdea53a3abfd5
# [('и', 59), ('в', 30), ('иннополис', 18), ('по', 16), ('2022', 15), ('на', 14), ('университет', 12), ('области', 10), ('с', 10), ('университета', 9)]

# %% [markdown]
# ## 1.5. [15] Crawling ##
#
# Method `crawl_generator()` is given starting url (`source`) and max depth of search. It should return a **generator** of `HtmlDocumentTextData` objects (return a document as soon as it is downloaded and parsed). You can benefit from `yield obj_name` python construction. Use `HtmlDocumentTextData.anchors` field to go deeper.

# %%
from queue import Queue


class Crawler:
    # def bfs(self):
    def _fetch(self,links):
        res = []
        for link in links:
            try:
                res.append(HtmlDocumentTextData(link))
            except:
                continue 
        return res

    def crawl_generator(self, source, depth=1):
        # TODO return real crawling results. Don't forget to process failures
        cur = self._fetch([source])
        result = set()
        if depth < 1:
            raise ValueError("Invalid Depth")
        for i in range(depth,0,-1):
            tmp = []
            for item in cur:
                result.add(item)
                tmp = [c[1] for c in item.doc.anchors]

            if not depth == 1 : cur = self._fetch(tmp)
        return list(result)

# %% [markdown]
# ### 1.5. Tests ###

# %%
crawler = Crawler()
counter = Counter()

for c in crawler.crawl_generator("https://innopolis.university/en/",2):
    print(c.doc.url)
    if c.doc.url[-4:] in ('.pdf', '.mp3', '.avi', '.mp4', '.txt'):
        print("Skipping", c.doc.url)
        continue
    counter.update(c.get_word_stats())
    print(len(counter), "distinct word(s) so far")
    
print("Done")

print(counter.most_common(20))
assert [x for x in counter.most_common(20) if x[0] == 'innopolis'], 'innopolis sould be among most common'
# Out:
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: 6e3c7c3d3e025ee168c16dd15a72f5f5bab21393f2bcdb696cb2c7538485b96f
# File loaded: 6e3c7c3d3e025ee168c16dd15a72f5f5bab21393f2bcdb696cb2c7538485b96f
# File loaded: 4c73a9d74a81f628e99a5fbe5dcc5b77ac5a156465371f37cd3d4b8ee381f1e7
# File loaded: 4c73a9d74a81f628e99a5fbe5dcc5b77ac5a156465371f37cd3d4b8ee381f1e7
# File loaded: 7945505a6233e923d4eae6421de20002a8a3b6aec9a8bc7b90f11bdbf18993c2
# File loaded: 7945505a6233e923d4eae6421de20002a8a3b6aec9a8bc7b90f11bdbf18993c2
# File loaded: 1c4c1ef250bb2f487d2e8eaee66037052ab1cbad1b902a79c9f436a04e66cccc
# File loaded: 1c4c1ef250bb2f487d2e8eaee66037052ab1cbad1b902a79c9f436a04e66cccc
# File loaded: ff4eaa88f13676c323953de7e92ec75139b9bfb38c0b94782dd54ae1cd2aba8b
# File loaded: ff4eaa88f13676c323953de7e92ec75139b9bfb38c0b94782dd54ae1cd2aba8b
# File loaded: cefa1c339b29c094ed67883bb6ebc56aebc27ab7e657358ca534e4b1052c918b
# File loaded: cefa1c339b29c094ed67883bb6ebc56aebc27ab7e657358ca534e4b1052c918b
# File loaded: 0a219bf773a7416030203479d6b68fdd2407ae7ad52ddb4a5d24b2bdb3eca5a4
# File loaded: 0a219bf773a7416030203479d6b68fdd2407ae7ad52ddb4a5d24b2bdb3eca5a4
# File loaded: 259a8ca1a16308bdb366a0b76606e0b731b810aa48871d2a948dd258a7a2873f
# File loaded: 259a8ca1a16308bdb366a0b76606e0b731b810aa48871d2a948dd258a7a2873f
# File loaded: 724498f9d8b2a79e0431cfe1b765322f24103d44cac01630add274f12b49d57a
# File loaded: 724498f9d8b2a79e0431cfe1b765322f24103d44cac01630add274f12b49d57a
# File loaded: 21b742009e5954c977ca11236446809a4089598c6b46e246fdaa583b09def39d
# File loaded: 21b742009e5954c977ca11236446809a4089598c6b46e246fdaa583b09def39d
# File loaded: 0dd4edae5676466365a08c6525f38f4f14385d096c1b0bf793894a1f414152c1
# File loaded: 0dd4edae5676466365a08c6525f38f4f14385d096c1b0bf793894a1f414152c1
# File loaded: 0dd4edae5676466365a08c6525f38f4f14385d096c1b0bf793894a1f414152c1
# File loaded: 0dd4edae5676466365a08c6525f38f4f14385d096c1b0bf793894a1f414152c1
# File loaded: 735a3a6e56c634cead5e3a79ac6c8debd87d26fcc47c0ff5eb4e6290a3c14462
# File loaded: 735a3a6e56c634cead5e3a79ac6c8debd87d26fcc47c0ff5eb4e6290a3c14462
# File loaded: ff72f9cf9746ff435b3a5a7203b0c9c1a37f839a1496df662069124ee9aac9d9
# File loaded: ff72f9cf9746ff435b3a5a7203b0c9c1a37f839a1496df662069124ee9aac9d9
# File loaded: a78c8ebd63419311d41130b6959b28501f69bec09b7c09cfa5452a4da869bb64
# File loaded: a78c8ebd63419311d41130b6959b28501f69bec09b7c09cfa5452a4da869bb64
# File loaded: 47b533e5e51d83a6419b798e78c61cecdbae641ee4f56f4b3f56d96250dd92ec
# File loaded: 47b533e5e51d83a6419b798e78c61cecdbae641ee4f56f4b3f56d96250dd92ec
# File loaded: 63ea3cb87fb32e543f67c6f60f4addc9712ac01eb87f78acb1de3cd59025c422
# File loaded: 63ea3cb87fb32e543f67c6f60f4addc9712ac01eb87f78acb1de3cd59025c422
# File loaded: a079b7cb35481f550f7e4d862930b2ebde99f05173b968cec624d57061bc7075
# File loaded: a079b7cb35481f550f7e4d862930b2ebde99f05173b968cec624d57061bc7075
# File loaded: cdaa8b1f69eea648e39b6f6cfb5f5dbe3e5019b8c8dcdf313c15307cb92e1615
# File loaded: cdaa8b1f69eea648e39b6f6cfb5f5dbe3e5019b8c8dcdf313c15307cb92e1615
# File loaded: c9a99d5815d176392443fbf8f2c83507ecaa4b7e28af82c1fa62e6dec00ccaeb
# File loaded: c9a99d5815d176392443fbf8f2c83507ecaa4b7e28af82c1fa62e6dec00ccaeb
# File loaded: 5052dcb07357c7686397c21b36ddc7a5debc334594b49072a913409323bbc261
# File loaded: 5052dcb07357c7686397c21b36ddc7a5debc334594b49072a913409323bbc261
# File loaded: 0879889f0a2153139d2b0ed6edbb2e8af6f2d3ba8f682759651a78f3ccd0f280
# File loaded: 0879889f0a2153139d2b0ed6edbb2e8af6f2d3ba8f682759651a78f3ccd0f280
# File loaded: 5276dc838be3f4c13f191d9df93201900fedb399a6cbdca01a8405c18dc36354
# File loaded: 5276dc838be3f4c13f191d9df93201900fedb399a6cbdca01a8405c18dc36354
# File loaded: 4242d6d246f5f41469687da4c68d8c1b01356d567fdf4c376ba6b5ae89178fc7
# File loaded: 4242d6d246f5f41469687da4c68d8c1b01356d567fdf4c376ba6b5ae89178fc7
# File loaded: b3db4a1871159a57fe2f8fe7066ad17ecd3032ce4dfca073eff52ab926a1eaf4
# File loaded: b3db4a1871159a57fe2f8fe7066ad17ecd3032ce4dfca073eff52ab926a1eaf4
# File loaded: a18fd59eb169a980d648cbe746a930ce0bbfa1756cf4ca3a22a3bb64ff8b7d39
# File loaded: a18fd59eb169a980d648cbe746a930ce0bbfa1756cf4ca3a22a3bb64ff8b7d39
# File loaded: cd785531b18dc498d1296180a46661906618c87c4f5f518c0b88de4a94b9bf3b
# File loaded: cd785531b18dc498d1296180a46661906618c87c4f5f518c0b88de4a94b9bf3b
# File loaded: d4a08a7b4250c5a00fe9993c073b0b860ef0d2f38318b185a9d5c0e9f3ca3b5f
# File loaded: d4a08a7b4250c5a00fe9993c073b0b860ef0d2f38318b185a9d5c0e9f3ca3b5f
# File loaded: fa6c1ea09c96df35449fadb9897fcfb0fdb9393738475c417247848916293865
# File loaded: fa6c1ea09c96df35449fadb9897fcfb0fdb9393738475c417247848916293865
# File loaded: 5611df150584b5d2f2167fa744122ee1d1fc7aa5deef16f613b464147be444ec
# File loaded: 5611df150584b5d2f2167fa744122ee1d1fc7aa5deef16f613b464147be444ec
# File loaded: c56a6bbe93f6b82f2fb1ef445932994aa044611c0052ee5a0a999af5650bbbfa
# File loaded: c56a6bbe93f6b82f2fb1ef445932994aa044611c0052ee5a0a999af5650bbbfa
# File loaded: da83edc5464ad7eb25d62267a127599b876f68b6702cd6567f6e47b101d1ddcf
# File loaded: da83edc5464ad7eb25d62267a127599b876f68b6702cd6567f6e47b101d1ddcf
# File loaded: 813cff808eec087c39cd08dd0f2ae5082b13f9dba88727d5c3ea20aefcc04c86
# File loaded: 813cff808eec087c39cd08dd0f2ae5082b13f9dba88727d5c3ea20aefcc04c86
# File loaded: e682a4aa287664e876856f97ae9e6b09f3e34c6f68240d0e5f25e37c03bf5a96
# File loaded: e682a4aa287664e876856f97ae9e6b09f3e34c6f68240d0e5f25e37c03bf5a96
# File loaded: acb442802bd405a8489da4768fd184f6b3e7d363994d4035b44c33ea67fc7638
# File loaded: acb442802bd405a8489da4768fd184f6b3e7d363994d4035b44c33ea67fc7638
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: 2205fa17c54d22b56aa13823afb11e5e58ab659626a8aeb6d31a7ad08be2ba22
# File loaded: 2205fa17c54d22b56aa13823afb11e5e58ab659626a8aeb6d31a7ad08be2ba22
# File loaded: 2d12411ab838d47ef7b2105097ae77977a1f3e9c5230ef555a216a0a720ef469
# File loaded: 2d12411ab838d47ef7b2105097ae77977a1f3e9c5230ef555a216a0a720ef469
# File loaded: 0eee718f404234555930eda80cb6b446b665985b3c6395dab4245e29dd4763dd
# File loaded: 0eee718f404234555930eda80cb6b446b665985b3c6395dab4245e29dd4763dd
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: 14f4a5e464b3aacb35b629d7c2d36a49de161581e91a61fc01c9794957d27cf9
# File loaded: 14f4a5e464b3aacb35b629d7c2d36a49de161581e91a61fc01c9794957d27cf9
# File loaded: c77ebb08d24ed3899a69b167ecceaf7fb00d8b76a0ccc695c3d13d2261656abd
# File loaded: c77ebb08d24ed3899a69b167ecceaf7fb00d8b76a0ccc695c3d13d2261656abd
# File loaded: 1af78f42358a965c8f3b403eb62840fabff87471f4f30201394028f9c8fc0520
# File loaded: 1af78f42358a965c8f3b403eb62840fabff87471f4f30201394028f9c8fc0520
# File loaded: 1c969e82e430fadf45fdcc1c3e575cd17413f51431fdc9df2716648b74662b2f
# File loaded: 1c969e82e430fadf45fdcc1c3e575cd17413f51431fdc9df2716648b74662b2f
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: 3e222e0ee1cc7ffd320f2504cf21572729c00c3043a1c63da0bc52ca008bde12
# File loaded: 3e222e0ee1cc7ffd320f2504cf21572729c00c3043a1c63da0bc52ca008bde12
# File loaded: 8d1ba73f21a26ebc35159d58dc6ccaa4402a7f4b01b2f9394cfba85845c4c2c0
# File loaded: 8d1ba73f21a26ebc35159d58dc6ccaa4402a7f4b01b2f9394cfba85845c4c2c0
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: bb2c35d59e2661ba6390d14e548690b2300dfd7dde1b2a8d255c503090d67188
# File loaded: bb2c35d59e2661ba6390d14e548690b2300dfd7dde1b2a8d255c503090d67188
# File loaded: 2ad716f3e1c7a00e55b49a0fe7c3825b53c7951d25c91812e2934850d787e9f2
# File loaded: 2ad716f3e1c7a00e55b49a0fe7c3825b53c7951d25c91812e2934850d787e9f2
# File loaded: 21b742009e5954c977ca11236446809a4089598c6b46e246fdaa583b09def39d
# File loaded: 21b742009e5954c977ca11236446809a4089598c6b46e246fdaa583b09def39d
# File loaded: f88caba96ddb80519b073c5a4778d8e3a507f289b0a0154efc08b2791c0d5d63
# File loaded: f88caba96ddb80519b073c5a4778d8e3a507f289b0a0154efc08b2791c0d5d63
# File loaded: bc28c50ff1f66f97231be5d9223235eab7a3a13d6dacd5ae5864d11ef58cb295
# File loaded: bc28c50ff1f66f97231be5d9223235eab7a3a13d6dacd5ae5864d11ef58cb295
# File loaded: 160af25c8b1cca0914d1192e2f89cac6a617125dadd52837fc2b86bfb7422022
# File loaded: 160af25c8b1cca0914d1192e2f89cac6a617125dadd52837fc2b86bfb7422022
# File loaded: 1fd69c1603033c0cc8672f31acc2a852828b7f9d49d0d01693bd54c25799ed2b
# File loaded: 1fd69c1603033c0cc8672f31acc2a852828b7f9d49d0d01693bd54c25799ed2b
# File loaded: b1efcddcb2675c34ab78dd7eadd35c1c9a64794419b97385315f0a38e5146826
# File loaded: b1efcddcb2675c34ab78dd7eadd35c1c9a64794419b97385315f0a38e5146826
# File loaded: 395e0459bb3ab58a0b86a7b9e4d519780732a61bc9a0281791611f2c8b02a115
# File loaded: 395e0459bb3ab58a0b86a7b9e4d519780732a61bc9a0281791611f2c8b02a115
# File loaded: a098b299ac4dd3ffe293ff4f93725462aef38ebd339d74e9bfafdea53a3abfd5
# File loaded: a098b299ac4dd3ffe293ff4f93725462aef38ebd339d74e9bfafdea53a3abfd5
# File loaded: 1c4c1ef250bb2f487d2e8eaee66037052ab1cbad1b902a79c9f436a04e66cccc
# File loaded: 1c4c1ef250bb2f487d2e8eaee66037052ab1cbad1b902a79c9f436a04e66cccc
# File loaded: 395e0459bb3ab58a0b86a7b9e4d519780732a61bc9a0281791611f2c8b02a115
# File loaded: 395e0459bb3ab58a0b86a7b9e4d519780732a61bc9a0281791611f2c8b02a115
# File loaded: a098b299ac4dd3ffe293ff4f93725462aef38ebd339d74e9bfafdea53a3abfd5
# File loaded: a098b299ac4dd3ffe293ff4f93725462aef38ebd339d74e9bfafdea53a3abfd5
# File loaded: 63ea3cb87fb32e543f67c6f60f4addc9712ac01eb87f78acb1de3cd59025c422
# File loaded: 63ea3cb87fb32e543f67c6f60f4addc9712ac01eb87f78acb1de3cd59025c422
# File loaded: 7e0971d52486a301330790ef944643e2262413215f5d5516fa8c0c9f25bf9fff
# File loaded: 7e0971d52486a301330790ef944643e2262413215f5d5516fa8c0c9f25bf9fff
# File loaded: a4cbe3d615e0d6689341cf47630e11cae0c61369cd629483e60375453a2d75f1
# File loaded: a4cbe3d615e0d6689341cf47630e11cae0c61369cd629483e60375453a2d75f1
# File loaded: ff72f9cf9746ff435b3a5a7203b0c9c1a37f839a1496df662069124ee9aac9d9
# File loaded: ff72f9cf9746ff435b3a5a7203b0c9c1a37f839a1496df662069124ee9aac9d9
# File loaded: 26edee9bbbdf96a2af253143caf456a20a5780ff9e968d8c8c850f258555c70f
# File loaded: 26edee9bbbdf96a2af253143caf456a20a5780ff9e968d8c8c850f258555c70f
# File loaded: a079b7cb35481f550f7e4d862930b2ebde99f05173b968cec624d57061bc7075
# File loaded: a079b7cb35481f550f7e4d862930b2ebde99f05173b968cec624d57061bc7075
# File loaded: 5052dcb07357c7686397c21b36ddc7a5debc334594b49072a913409323bbc261
# File loaded: 5052dcb07357c7686397c21b36ddc7a5debc334594b49072a913409323bbc261
# File loaded: cd785531b18dc498d1296180a46661906618c87c4f5f518c0b88de4a94b9bf3b
# File loaded: cd785531b18dc498d1296180a46661906618c87c4f5f518c0b88de4a94b9bf3b
# File loaded: 413d6aababa42143f4f2ec28ef37b0a95db35864eeff2f7e3c9ec6de1350279b
# File loaded: 413d6aababa42143f4f2ec28ef37b0a95db35864eeff2f7e3c9ec6de1350279b
# File loaded: fa6c1ea09c96df35449fadb9897fcfb0fdb9393738475c417247848916293865
# File loaded: fa6c1ea09c96df35449fadb9897fcfb0fdb9393738475c417247848916293865
# File loaded: acb442802bd405a8489da4768fd184f6b3e7d363994d4035b44c33ea67fc7638
# File loaded: acb442802bd405a8489da4768fd184f6b3e7d363994d4035b44c33ea67fc7638
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: 73a8ead7116bca0b2b985c3539cc4450653e6679403d9e3b6a9b00196fb3cfa9
# File loaded: 73a8ead7116bca0b2b985c3539cc4450653e6679403d9e3b6a9b00196fb3cfa9
# File loaded: 73a8ead7116bca0b2b985c3539cc4450653e6679403d9e3b6a9b00196fb3cfa9
# File loaded: 73a8ead7116bca0b2b985c3539cc4450653e6679403d9e3b6a9b00196fb3cfa9
# File loaded: 796e30bc207c35fbe1f6a7823eb72c1359211e75ac755e7c53828c2c5bece9c0
# File loaded: 796e30bc207c35fbe1f6a7823eb72c1359211e75ac755e7c53828c2c5bece9c0
# File loaded: 664bd404056313cce1a0442677b1541366eac5d849d35db263fc3e2dc671e4f3
# File loaded: 664bd404056313cce1a0442677b1541366eac5d849d35db263fc3e2dc671e4f3
# File loaded: 40ae14622460e506515ea81484849ff23be57caff425e406f200b031f200df6e
# File loaded: 40ae14622460e506515ea81484849ff23be57caff425e406f200b031f200df6e
# File loaded: add4664c5598b4c4a86099337a3299f97e021e97f87ad99640a781cd9e926d18
# File loaded: add4664c5598b4c4a86099337a3299f97e021e97f87ad99640a781cd9e926d18
# File loaded: 06679d1e8a31cb1a9158cf19448fb3deaefbe674f798cae2cf225516f44eebcb
# File loaded: 06679d1e8a31cb1a9158cf19448fb3deaefbe674f798cae2cf225516f44eebcb
# File loaded: 7fab23247f46ed6b7e406d4ff5c1eeb798cc4b8a46b66eecc4da19653a9e2d1c
# File loaded: 7fab23247f46ed6b7e406d4ff5c1eeb798cc4b8a46b66eecc4da19653a9e2d1c
# File loaded: 8ed06625646b9e7d20729af28820d5bf0bf74057d193ba013d2660ec9cf7e057
# File loaded: 8ed06625646b9e7d20729af28820d5bf0bf74057d193ba013d2660ec9cf7e057
# File loaded: f78f5e06faf191831cd56138ca22dde75bd6bbeb95c8096ed7c7f230e7d1e0b3
# File loaded: f78f5e06faf191831cd56138ca22dde75bd6bbeb95c8096ed7c7f230e7d1e0b3
# File loaded: 2184e71cd6803dad5ed855e019b0cfe44f2f50bbedbe691a4b3c04da93b8c2fc
# File loaded: 2184e71cd6803dad5ed855e019b0cfe44f2f50bbedbe691a4b3c04da93b8c2fc
# File loaded: 842323a07f12da6dbe2238cd8d97ad5297d7ba722b1547d6a1f524cb65614284
# File loaded: 842323a07f12da6dbe2238cd8d97ad5297d7ba722b1547d6a1f524cb65614284
# File loaded: 00eb3fd33a76dd206f6496d2ba7ac6e5735c8c358b0a74cb86c09cd19b9cff74
# File loaded: 00eb3fd33a76dd206f6496d2ba7ac6e5735c8c358b0a74cb86c09cd19b9cff74
# File loaded: f5a7c16acbb9f639024555a7888082656f71c0003663822458a0e064b32ed6d2
# File loaded: f5a7c16acbb9f639024555a7888082656f71c0003663822458a0e064b32ed6d2
# File loaded: 2dc73858564b7545c77c8af8eff5a63c77dafb98b22149920b60c05fae12a968
# File loaded: 2dc73858564b7545c77c8af8eff5a63c77dafb98b22149920b60c05fae12a968
# File loaded: 26edee9bbbdf96a2af253143caf456a20a5780ff9e968d8c8c850f258555c70f
# File loaded: 26edee9bbbdf96a2af253143caf456a20a5780ff9e968d8c8c850f258555c70f
# File loaded: ff72f9cf9746ff435b3a5a7203b0c9c1a37f839a1496df662069124ee9aac9d9
# File loaded: ff72f9cf9746ff435b3a5a7203b0c9c1a37f839a1496df662069124ee9aac9d9
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: e7552a1277a7d9ed9b7d2e7b80d8b52cb0620b6772c027524733d1e71af578f4
# File loaded: e7552a1277a7d9ed9b7d2e7b80d8b52cb0620b6772c027524733d1e71af578f4
# File loaded: 47b533e5e51d83a6419b798e78c61cecdbae641ee4f56f4b3f56d96250dd92ec
# File loaded: 47b533e5e51d83a6419b798e78c61cecdbae641ee4f56f4b3f56d96250dd92ec
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: 90e132578c6326dfed4782adce4eebbd5f29dbd3ddeba9342c928a5b12e4a47e
# File loaded: 90e132578c6326dfed4782adce4eebbd5f29dbd3ddeba9342c928a5b12e4a47e
# File loaded: da9c5a11c37ff6f542adb0b5855dbfd8e1f087f3e721960d8b03231956971b35
# File loaded: da9c5a11c37ff6f542adb0b5855dbfd8e1f087f3e721960d8b03231956971b35
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b1c10b8b82cfc2a140c0eb3e9dbfbfe00e1ff35f4a266c5ab112895a069ad96e
# File loaded: b735ed7973bd0abfcc125ad5561c360defe8d33664969b58abb5dbbf3e27a04b
# File loaded: b735ed7973bd0abfcc125ad5561c360defe8d33664969b58abb5dbbf3e27a04b
# File loaded: 381ae4d06d96d1068cfded05a958f1101869ac85d847dca2c1c09568efe1d2f5
# File loaded: 381ae4d06d96d1068cfded05a958f1101869ac85d847dca2c1c09568efe1d2f5
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# File loaded: a68150a59ac36ca758d9d13ffb560ade83f2aea9707d5703c07b9b736dd5181a
# File loaded: a68150a59ac36ca758d9d13ffb560ade83f2aea9707d5703c07b9b736dd5181a
# File loaded: 9e43dcc3e3ef2d03704e12cbd315f9cb5b1d1770b9b56a974ee83f9c044f0163
# File loaded: 9e43dcc3e3ef2d03704e12cbd315f9cb5b1d1770b9b56a974ee83f9c044f0163
# File loaded: 7b241203abaac188ad973813b3935582093e269e1c793730b464d57d2fce26e1
# File loaded: 7b241203abaac188ad973813b3935582093e269e1c793730b464d57d2fce26e1
# File loaded: 5f45553c4897b1cdb53ec435cb5b2ef25675fce8632fe81bbf554ab05d2a9d5c
# File loaded: 5f45553c4897b1cdb53ec435cb5b2ef25675fce8632fe81bbf554ab05d2a9d5c
# File loaded: 22f2aae924a6d457284dfff57c3a2701b2f0f205b7ea6aadb5311cb8b905073a
# File loaded: 22f2aae924a6d457284dfff57c3a2701b2f0f205b7ea6aadb5311cb8b905073a
# File loaded: 151dd226e3aba697c639f3581ff949247f32583be67d37e4703542faf41d0c95
# File loaded: 151dd226e3aba697c639f3581ff949247f32583be67d37e4703542faf41d0c95
# File loaded: 0958bc95498c022f38de6e7d2b6778953c19a7ef4a09eba156ddab15c9f1b480
# File loaded: 0958bc95498c022f38de6e7d2b6778953c19a7ef4a09eba156ddab15c9f1b480
# 404 NOT FOUND for http://www.minsvyaz.ru/en/None
# File loaded: 7c59491f76ff196c75ffed6e8b58c77a8bc8102ee9fedb49c3039814d4aabb7c
# File loaded: 7c59491f76ff196c75ffed6e8b58c77a8bc8102ee9fedb49c3039814d4aabb7c
# File loaded: 7c59491f76ff196c75ffed6e8b58c77a8bc8102ee9fedb49c3039814d4aabb7c
# File loaded: 7c59491f76ff196c75ffed6e8b58c77a8bc8102ee9fedb49c3039814d4aabb7c
# File loaded: 7b241203abaac188ad973813b3935582093e269e1c793730b464d57d2fce26e1
# File loaded: 7b241203abaac188ad973813b3935582093e269e1c793730b464d57d2fce26e1
# File loaded: b3dc0900c80f92dbc84a750983286361e810bede9547025f5ae40126d51fa562
# File loaded: b3dc0900c80f92dbc84a750983286361e810bede9547025f5ae40126d51fa562
# File loaded: 7556431c32bfd1f33e73a2aa2be8a7493e476d051fcf4dcf565e0dacdc07ca1f
# File loaded: 7556431c32bfd1f33e73a2aa2be8a7493e476d051fcf4dcf565e0dacdc07ca1f
# File loaded: ba69f0feb466dfa6bbe7b52ddd0830bbea54c5df2551fcd0f12946342faad8c3
# File loaded: ba69f0feb466dfa6bbe7b52ddd0830bbea54c5df2551fcd0f12946342faad8c3
# File loaded: 57840e4865b1e94c03cf514c9176d40c709bae1e441aadfd612fda28f3d679e2
# File loaded: 57840e4865b1e94c03cf514c9176d40c709bae1e441aadfd612fda28f3d679e2
# File loaded: 7b241203abaac188ad973813b3935582093e269e1c793730b464d57d2fce26e1
# File loaded: 7b241203abaac188ad973813b3935582093e269e1c793730b464d57d2fce26e1
# File loaded: fdb670391b379b3f13a0366ae544e3e442decab4ac86e8547dd345e0db49a2b1
# File loaded: fdb670391b379b3f13a0366ae544e3e442decab4ac86e8547dd345e0db49a2b1
# File loaded: e29bb6c71884eb48ba853ab508ac12cc7bb932ea3aca37b1d4d5577138717ba4
# File loaded: e29bb6c71884eb48ba853ab508ac12cc7bb932ea3aca37b1d4d5577138717ba4
# File loaded: 5012d59b580945f827e5f3ad62599bc603842c54e83ee058dc20663af8593321
# File loaded: 5012d59b580945f827e5f3ad62599bc603842c54e83ee058dc20663af8593321
# File loaded: 52320d66c49f1f1001aaa45196ddff54e2f7d66d8987500fdf8023f497c24a6e
# File loaded: 52320d66c49f1f1001aaa45196ddff54e2f7d66d8987500fdf8023f497c24a6e
# File loaded: a514ac7a324bd29cc203e1b6bc2dd2298db344a0a7f78307d5ddb3253d0a4520
# File loaded: a514ac7a324bd29cc203e1b6bc2dd2298db344a0a7f78307d5ddb3253d0a4520
# File loaded: f8e51244d04bcca19075f391a5d9c671494734c0e3abe2302bddf2ca38791e7d
# File loaded: f8e51244d04bcca19075f391a5d9c671494734c0e3abe2302bddf2ca38791e7d
# File loaded: bdbb0f77befae96cf3a81df1459c144a4e4503c6e6dec8f50ec643584f414999
# File loaded: bdbb0f77befae96cf3a81df1459c144a4e4503c6e6dec8f50ec643584f414999
# File loaded: a01773af8fef2ded20bf755a33765ca23baea4f09b15093d43285db33c976a6f
# File loaded: a01773af8fef2ded20bf755a33765ca23baea4f09b15093d43285db33c976a6f
# File loaded: cfcb7a06022da771c210f66a8e5a2808a94ea3a1aff2eff0d6e8fcb5e2f5ff51
# File loaded: cfcb7a06022da771c210f66a8e5a2808a94ea3a1aff2eff0d6e8fcb5e2f5ff51
# File loaded: 3f666ff1d43e623829c0b981f5793227f34a2e561662e03d0d8749bc9c5d805c
# File loaded: 3f666ff1d43e623829c0b981f5793227f34a2e561662e03d0d8749bc9c5d805c
# File loaded: 009a98ed8a2cf716f4d19e90c3dc6d4cda649b56989d303c582709d3fad7f4cc
# File loaded: 009a98ed8a2cf716f4d19e90c3dc6d4cda649b56989d303c582709d3fad7f4cc
# File loaded: bd591fda863535beb69ac6457a4ff6fb1f9e73b0f44f9ba177804e78a438c7aa
# File loaded: bd591fda863535beb69ac6457a4ff6fb1f9e73b0f44f9ba177804e78a438c7aa
# File loaded: 4cb678fbecee67d295ded1fe36f27dc75e58e5bb2a77f43b41f55311d4d0dda6
# File loaded: 4cb678fbecee67d295ded1fe36f27dc75e58e5bb2a77f43b41f55311d4d0dda6
# File loaded: e6e5b5be6dd7bac842ec8e40554f9dceef8f46a92963fac0204371c6082dad7b
# File loaded: e6e5b5be6dd7bac842ec8e40554f9dceef8f46a92963fac0204371c6082dad7b
# File loaded: 0ef47135863abc0152b882f18c4aad919182186faf97c0273fb30e6c367f7514
# File loaded: 0ef47135863abc0152b882f18c4aad919182186faf97c0273fb30e6c367f7514
# File loaded: 151dd226e3aba697c639f3581ff949247f32583be67d37e4703542faf41d0c95
# File loaded: 151dd226e3aba697c639f3581ff949247f32583be67d37e4703542faf41d0c95
# File loaded: e29bb6c71884eb48ba853ab508ac12cc7bb932ea3aca37b1d4d5577138717ba4
# File loaded: e29bb6c71884eb48ba853ab508ac12cc7bb932ea3aca37b1d4d5577138717ba4
# File loaded: 7c3379c8f7280830a8fac942e823cbd01b26e613d2dfacfd94c98ab9d679d505
# File loaded: 7c3379c8f7280830a8fac942e823cbd01b26e613d2dfacfd94c98ab9d679d505
# File loaded: b735ed7973bd0abfcc125ad5561c360defe8d33664969b58abb5dbbf3e27a04b
# File loaded: b735ed7973bd0abfcc125ad5561c360defe8d33664969b58abb5dbbf3e27a04b
# File loaded: 151dd226e3aba697c639f3581ff949247f32583be67d37e4703542faf41d0c95
# File loaded: 151dd226e3aba697c639f3581ff949247f32583be67d37e4703542faf41d0c95
# File loaded: b735ed7973bd0abfcc125ad5561c360defe8d33664969b58abb5dbbf3e27a04b
# File loaded: b735ed7973bd0abfcc125ad5561c360defe8d33664969b58abb5dbbf3e27a04b
# File loaded: 151dd226e3aba697c639f3581ff949247f32583be67d37e4703542faf41d0c95
# File loaded: 151dd226e3aba697c639f3581ff949247f32583be67d37e4703542faf41d0c95
# File loaded: 51382c5688a0dc7ea0f8020ec96b5a47413bd2b620bd93a201ec4143777b8e35
# File loaded: 51382c5688a0dc7ea0f8020ec96b5a47413bd2b620bd93a201ec4143777b8e35
# File loaded: 0958bc95498c022f38de6e7d2b6778953c19a7ef4a09eba156ddab15c9f1b480
# File loaded: 0958bc95498c022f38de6e7d2b6778953c19a7ef4a09eba156ddab15c9f1b480
# File loaded: a881b2e9032e11a8b3017aa9c33160a63afff360ff0c8bd534db942bee8ff4ad
# File loaded: a881b2e9032e11a8b3017aa9c33160a63afff360ff0c8bd534db942bee8ff4ad
# File loaded: 9e43dcc3e3ef2d03704e12cbd315f9cb5b1d1770b9b56a974ee83f9c044f0163
# File loaded: 9e43dcc3e3ef2d03704e12cbd315f9cb5b1d1770b9b56a974ee83f9c044f0163
# File loaded: cf0ff95d7853a79b612e55a416085a16b453aeba8a221eb995c1934b95ede8ea
# File loaded: cf0ff95d7853a79b612e55a416085a16b453aeba8a221eb995c1934b95ede8ea
# File loaded: 8ac23291fa6f60ddd60199438e6e854af2909e156d91bdb02b286d13288284bc
# File loaded: 8ac23291fa6f60ddd60199438e6e854af2909e156d91bdb02b286d13288284bc
# File loaded: 151dd226e3aba697c639f3581ff949247f32583be67d37e4703542faf41d0c95
# File loaded: 151dd226e3aba697c639f3581ff949247f32583be67d37e4703542faf41d0c95
# File loaded: e29bb6c71884eb48ba853ab508ac12cc7bb932ea3aca37b1d4d5577138717ba4
# File loaded: e29bb6c71884eb48ba853ab508ac12cc7bb932ea3aca37b1d4d5577138717ba4
# File loaded: 85249f1e38c72e3939ebc121bc04b60672ce5285da4037f6e87605c663f07802
# File loaded: 85249f1e38c72e3939ebc121bc04b60672ce5285da4037f6e87605c663f07802
# File loaded: 7c3379c8f7280830a8fac942e823cbd01b26e613d2dfacfd94c98ab9d679d505
# File loaded: 7c3379c8f7280830a8fac942e823cbd01b26e613d2dfacfd94c98ab9d679d505
# File loaded: 86e811ba0af6592c3063fe61c46fa85d9a65686b63016b0870ebc967def713f2
# File loaded: 86e811ba0af6592c3063fe61c46fa85d9a65686b63016b0870ebc967def713f2
# https://innopolis.university/en/team-structure/techcenters/
# 232 distinct word(s) so far
# https://career.innopolis.university/en/job/
# 1251 distinct word(s) so far
# https://innopolis.university/en/international-relations-office/
# 1813 distinct word(s) so far
# https://dovuz.innopolis.university/
# 2309 distinct word(s) so far
# https://innopolis.university/en/
# 2406 distinct word(s) so far
# https://apply.innopolis.university/en/
# 3083 distinct word(s) so far
# https://innopolis.university/en/
# 3083 distinct word(s) so far
# https://innopolis.university/en/research/
# 3162 distinct word(s) so far
# https://innopolis.university/en/incomingstudents/
# 3270 distinct word(s) so far
# https://apply.innopolis.university/en/master/robotics/
# 3507 distinct word(s) so far
# https://innopolis.university/en/team-structure/techcenters/
# 3507 distinct word(s) so far
# https://apply.innopolis.university/en/master/datascience/
# 3675 distinct word(s) so far
# https://www.youtube.com/user/InnopolisU
# 3686 distinct word(s) so far
# https://innopolis.university/en/
# 3686 distinct word(s) so far
# https://alumni.innopolis.university/
# 4055 distinct word(s) so far
# https://innopolis.university/en/organizatsiya-i-provedenie-meropriyatiy/
# 4343 distinct word(s) so far
# https://innopolis.university/en/international-relations-office/
# 4343 distinct word(s) so far
# https://career.innopolis.university/en/
# 4646 distinct word(s) so far
# https://university.innopolis.ru/en/cooperation/
# 4652 distinct word(s) so far
# https://apply.innopolis.university/en
# 4652 distinct word(s) so far
# https://innopolis.university/en/board/
# 4732 distinct word(s) so far
# https://innopolis.university/en/
# 4732 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/DS-AI/
# 4833 distinct word(s) so far
# https://vk.com/innopolisu
# 5077 distinct word(s) so far
# https://innopolis.university/en/lab-game-development/
# 5151 distinct word(s) so far
# https://panoroo.com/virtual-tours/NvQZM6B2
# 5152 distinct word(s) so far
# https://innopolis.university/en/internationalpartners/
# 5160 distinct word(s) so far
# https://innopolis.university/en/campus
# 5304 distinct word(s) so far
# https://innopolis.university/lk/
# 5593 distinct word(s) so far
# https://media.innopolis.university/en/news/
# 5646 distinct word(s) so far
# https://career.innopolis.university/en/
# 5646 distinct word(s) so far
# https://media.innopolis.university/en/events/
# 5652 distinct word(s) so far
# https://innopolis.university/en/team-structure/
# 5660 distinct word(s) so far
# https://innopolis.university/en/lab-operating-systems/
# 5717 distinct word(s) so far
# https://innopolis.university/en/lab-robotics/
# 5871 distinct word(s) so far
# https://innopolis.university/en/about/
# 5968 distinct word(s) so far
# https://innopolis.university/en/
# 5968 distinct word(s) so far
# https://apply.innopolis.university/en/master/technological-entrepreneurship/
# 6243 distinct word(s) so far
# https://innopolis.university/en/
# 6243 distinct word(s) so far
# https://innopolis.university/en/
# 6243 distinct word(s) so far
# https://media.innopolis.university/news/innopolis-university-extends-international-application-deadline-/
# 6361 distinct word(s) so far
# https://media.innopolis.university/en/
# 6361 distinct word(s) so far
# https://innopolis.university/en/contacts/
# 6378 distinct word(s) so far
# https://innopolis.university/en/faculty/
# 7210 distinct word(s) so far
# https://innopolis.university/en/
# 7210 distinct word(s) so far
# https://apply.innopolis.ru/en/index.php
# 7555 distinct word(s) so far
# https://innopolis.university/en/
# 7555 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/CE/
# 7574 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/
# 7610 distinct word(s) so far
# https://innopolis.university/en/faculty/
# 7610 distinct word(s) so far
# https://apply.innopolis.university/en/master/
# 7633 distinct word(s) so far
# https://media.innopolis.university/news/cyber-resilience-petrenko/
# 7842 distinct word(s) so far
# https://innopolis.university/en/lab-cyberphysical-systems/
# 7892 distinct word(s) so far
# https://innopolis.university/en/
# 7892 distinct word(s) so far
# http://www.campuslife.innopolis.ru
# 8007 distinct word(s) so far
# https://innopolis.university/en/
# 8007 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/
# 8007 distinct word(s) so far
# https://innopolis.university/en/proekty/podderzhka-innovacionnoj-deyatelnosti/
# 8063 distinct word(s) so far
# https://innopolis.university/en/mlkr/
# 8242 distinct word(s) so far
# https://innopolis.university/en/lab-networks-blockchain/
# 8309 distinct word(s) so far
# https://media.innopolis.university/news/registration-innopolis-open-2020/
# 8411 distinct word(s) so far
# https://www.instagram.com/innopolisu/
# 8411 distinct word(s) so far
# https://www.facebook.com/InnopolisU
# 8411 distinct word(s) so far
# https://innopolis.university/en/teachingexcellencecenter/
# 8658 distinct word(s) so far
# https://innopolis.university/en/?special=Y
# 8665 distinct word(s) so far
# https://apply.innopolis.university/en/postgraduate-study/
# 8762 distinct word(s) so far
# https://media.innopolis.university/news/webinar-for-international-candidates-/
# 8778 distinct word(s) so far
# https://innopolis.university/en/lab-bioinformatics/
# 8829 distinct word(s) so far
# https://innopolis.university/en/
# 8829 distinct word(s) so far
# https://media.innopolis.university/news/devops-summer-school/
# 8947 distinct word(s) so far
# https://media.innopolis.university/news/webinar-interstudents-eng/
# 8977 distinct word(s) so far
# https://innopolis.university/search/
# 8979 distinct word(s) so far
# https://innopolis.university/en/proekty/activity/
# 9036 distinct word(s) so far
# https://innopolis.university/en/startupstudio/
# 9090 distinct word(s) so far
# https://university.innopolis.ru/en/about/
# 9090 distinct word(s) so far
# https://innopolis.university/en/contacts/
# 9090 distinct word(s) so far
# https://innopolis.university/lk/
# 9090 distinct word(s) so far
# https://media.innopolis.university/news/clobal-ai-challenge/
# 9173 distinct word(s) so far
# https://innopolis.university/en/
# 9173 distinct word(s) so far
# https://university.innopolis.ru/en/about/
# 9173 distinct word(s) so far
# https://innopolis.university/en/lab-software-service-engineering/
# 9273 distinct word(s) so far
# https://innopolis.university/en/lab-industrializing-software/
# 9317 distinct word(s) so far
# https://media.innopolis.university/news/clobal-ai-challenge/
# 9317 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/
# 9340 distinct word(s) so far
# https://innopolis.university/en/
# 9340 distinct word(s) so far
# https://innopolis.university/en/ido/
# 9402 distinct word(s) so far
# https://innopolis.university/en/outgoingstudents/
# 9440 distinct word(s) so far
# https://apply.innopolis.university/en/master/securityandnetworkengineering/
# 9524 distinct word(s) so far
# https://innopolis.university/
# 9639 distinct word(s) so far
# https://apply.innopolis.university/en/master/development/
# 9708 distinct word(s) so far
# https://apply.innopolis.university/en/stud-life/
# 9778 distinct word(s) so far
# https://innopolis.university/en/research/
# 9778 distinct word(s) so far
# https://corporate.innopolis.university/en
# 9870 distinct word(s) so far
# https://apply.innopolis.university/en/
# 9870 distinct word(s) so far
# https://innopolis.university/en/
# 9870 distinct word(s) so far
# https://apply.innopolis.university/en/postgraduate-study/
# 9870 distinct word(s) so far
# https://career.innopolis.university/en/
# 9870 distinct word(s) so far
# https://media.innopolis.university/en
# 9870 distinct word(s) so far
# https://innopolis.university/en/team/
# 9873 distinct word(s) so far
# https://innopolis.university/search/
# 9873 distinct word(s) so far
# https://innopolis.university/en/lab-oil-gas/
# 9923 distinct word(s) so far
# https://innopolis.university/en/
# 9923 distinct word(s) so far
# https://innopolis.university/en/
# 9923 distinct word(s) so far
# https://innopolis.university/
# 9923 distinct word(s) so far
# https://apply.innopolis.university/en/master/
# 9923 distinct word(s) so far
# https://innopolis.university/en/team-structure/education-academics/
# 9928 distinct word(s) so far
# https://innopolis.university/en/
# 9928 distinct word(s) so far
# https://innopolis.university/en/
# 9928 distinct word(s) so far
# https://innopolis.university/en/
# 9928 distinct word(s) so far
# http://www.minsvyaz.ru/en/
# 10029 distinct word(s) so far
# Done
# [('and', 5264), ('of', 4757), ('the', 3924), ('in', 2682), ('to', 1794), ('university', 1466), ('a', 1320), ('for', 1231), ('research', 858), ('innopolis', 854), ('at', 800), ('it', 752), ('you', 691), ('и', 625), ('is', 620), ('development', 607), ('software', 594), ('on', 592), ('education', 586), ('with', 561)]
